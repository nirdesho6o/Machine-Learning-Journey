# %% [markdown]
# ## outlier detection : they are necessary in cases such as fraud detection

# %% [markdown]
# ## outfliers affect ; linear reg, logistic reg, adaboost and deep learning also but they do not affect decision tress,random forest

# %% [markdown]
# ## how to deal with outliers
# ### trimming          ,,,,     missing value
# ### capping      ,,,          discretization

# %% [markdown]
# ## how to detect outliers: using normal distribution with miu +-3sigma
# ## skewed distribution using IQR based filtering
# ## using percentile
# ## winsorization

# %% [markdown]
# # Using Z-score
